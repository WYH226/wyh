# %%
# 代码块 1
print("你好!这是我的第一个Jupyter Notebook代码")
# 计算简单的数学
result = 5 + 3
print(f"5 + 3 = {result}")
# Out:
# 你好!这是我的第一个Jupyter Notebook代码
# 5 + 3 = 8

# %%
# 代码块 2
a = 10
b = 5
sum_ab = a + b
print(f"{a}+{b}={sum_ab}")
# Out:
# 10+5=15

# %%
# 代码块 3
difference = a - b
print(f"{a}-{b}={difference}")
# Out:
# 10-5=5
